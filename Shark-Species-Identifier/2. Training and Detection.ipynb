# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
files
# Out:
# {'PIPELINE_CONFIG': 'Tensorflow\\workspace\\models\\my_ssd_mobnet\\pipeline.config',
#  'TF_RECORD_SCRIPT': 'Tensorflow\\scripts\\generate_tfrecord.py',
#  'LABELMAP': 'Tensorflow\\workspace\\annotations\\label_map.pbtxt'}

# %% [markdown]
# # 1. Download Tenserflow Pretrained Models from Tensorflow Model Zoo

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (3.2)

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2023-02-14 13:29:57.193284: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2023-02-14 13:29:57.193400: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-14 13:30:11.560499: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2023-02-14 13:30:11.560610: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-14 13:30:11.568105: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: LAPTOP-6L4498N5
# 2023-02-14 13:30:11.568327: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: LAPTOP-6L4498N5
# Running tests under Python 3.10.4: C:\Users\matte\Documents\TCDCollege\4-FourthYear\CSU44099-FinalYearProject\Fishnet\Shark-Species-Identifier\identificationSystem\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-02-14 13:30:11.589960: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# C:\Users\matte\Documents\TCDCollege\4-FourthYear\CSU44099-FinalYearProject\Fishnet\Shark-Species-Identifier\identificationSystem\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0214 13:30:12.106010 11044 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.9s
# I0214 13:30:12.474989 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.9s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.71s
# I0214 13:30:14.188084 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.71s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.32s
# I0214 13:30:14.513630 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.32s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.39s
# I0214 13:30:14.900374 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.39s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# C:\Python310\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.81s
# I0214 13:30:17.712130 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.81s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0214 13:30:17.740807 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0214 13:30:17.766547 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0214 13:30:17.785821 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I0214 13:30:17.807231 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.12s
# I0214 13:30:17.928333 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.12s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.11s
# I0214 13:30:18.044899 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.12s
# I0214 13:30:18.162486 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.12s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.14s
# I0214 13:30:18.305942 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.14s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.13s
# I0214 13:30:18.438252 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.04s
# I0214 13:30:18.475033 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.04s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0214 13:30:18.674600 11044 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0214 13:30:18.674600 11044 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I0214 13:30:18.674600 11044 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# I0214 13:30:18.681349 11044 efficientnet_model.py:143] round_filter input=32 output=32
# I0214 13:30:18.713647 11044 efficientnet_model.py:143] round_filter input=32 output=32
# I0214 13:30:18.713647 11044 efficientnet_model.py:143] round_filter input=16 output=16
# I0214 13:30:18.825020 11044 efficientnet_model.py:143] round_filter input=16 output=16
# I0214 13:30:18.825020 11044 efficientnet_model.py:143] round_filter input=24 output=24
# I0214 13:30:19.053906 11044 efficientnet_model.py:143] round_filter input=24 output=24
# I0214 13:30:19.053906 11044 efficientnet_model.py:143] round_filter input=40 output=40
# I0214 13:30:19.284606 11044 efficientnet_model.py:143] round_filter input=40 output=40
# I0214 13:30:19.284606 11044 efficientnet_model.py:143] round_filter input=80 output=80
# I0214 13:30:19.746101 11044 efficientnet_model.py:143] round_filter input=80 output=80
# I0214 13:30:19.746101 11044 efficientnet_model.py:143] round_filter input=112 output=112
# I0214 13:30:20.078640 11044 efficientnet_model.py:143] round_filter input=112 output=112
# I0214 13:30:20.078640 11044 efficientnet_model.py:143] round_filter input=192 output=192
# I0214 13:30:20.575946 11044 efficientnet_model.py:143] round_filter input=192 output=192
# I0214 13:30:20.575946 11044 efficientnet_model.py:143] round_filter input=320 output=320
# I0214 13:30:20.693898 11044 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0214 13:30:20.768547 11044 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0214 13:30:20.828840 11044 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0214 13:30:20.828840 11044 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I0214 13:30:20.829340 11044 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 4
# I0214 13:30:20.830343 11044 efficientnet_model.py:143] round_filter input=32 output=32
# I0214 13:30:20.845934 11044 efficientnet_model.py:143] round_filter input=32 output=32
# I0214 13:30:20.845934 11044 efficientnet_model.py:143] round_filter input=16 output=16
# I0214 13:30:21.024507 11044 efficientnet_model.py:143] round_filter input=16 output=16
# I0214 13:30:21.024507 11044 efficientnet_model.py:143] round_filter input=24 output=24
# I0214 13:30:21.354996 11044 efficientnet_model.py:143] round_filter input=24 output=24
# I0214 13:30:21.355998 11044 efficientnet_model.py:143] round_filter input=40 output=40
# I0214 13:30:21.703534 11044 efficientnet_model.py:143] round_filter input=40 output=40
# I0214 13:30:21.703534 11044 efficientnet_model.py:143] round_filter input=80 output=80
# I0214 13:30:22.165782 11044 efficientnet_model.py:143] round_filter input=80 output=80
# I0214 13:30:22.165782 11044 efficientnet_model.py:143] round_filter input=112 output=112
# I0214 13:30:22.635996 11044 efficientnet_model.py:143] round_filter input=112 output=112
# I0214 13:30:22.636744 11044 efficientnet_model.py:143] round_filter input=192 output=192
# I0214 13:30:23.255880 11044 efficientnet_model.py:143] round_filter input=192 output=192
# I0214 13:30:23.255880 11044 efficientnet_model.py:143] round_filter input=320 output=320
# I0214 13:30:23.525409 11044 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0214 13:30:23.575922 11044 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0214 13:30:23.656068 11044 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0214 13:30:23.656068 11044 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 112
# I0214 13:30:23.658081 11044 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 5
# I0214 13:30:23.659084 11044 efficientnet_model.py:143] round_filter input=32 output=32
# I0214 13:30:23.675933 11044 efficientnet_model.py:143] round_filter input=32 output=32
# I0214 13:30:23.675933 11044 efficientnet_model.py:143] round_filter input=16 output=16
# I0214 13:30:23.843854 11044 efficientnet_model.py:143] round_filter input=16 output=16
# I0214 13:30:23.846021 11044 efficientnet_model.py:143] round_filter input=24 output=24
# I0214 13:30:24.155952 11044 efficientnet_model.py:143] round_filter input=24 output=24
# I0214 13:30:24.155952 11044 efficientnet_model.py:143] round_filter input=40 output=48
# I0214 13:30:24.488976 11044 efficientnet_model.py:143] round_filter input=40 output=48
# I0214 13:30:24.488976 11044 efficientnet_model.py:143] round_filter input=80 output=88
# I0214 13:30:24.923918 11044 efficientnet_model.py:143] round_filter input=80 output=88
# I0214 13:30:24.923918 11044 efficientnet_model.py:143] round_filter input=112 output=120
# I0214 13:30:25.375696 11044 efficientnet_model.py:143] round_filter input=112 output=120
# I0214 13:30:25.375696 11044 efficientnet_model.py:143] round_filter input=192 output=208
# I0214 13:30:25.964916 11044 efficientnet_model.py:143] round_filter input=192 output=208
# I0214 13:30:25.964916 11044 efficientnet_model.py:143] round_filter input=320 output=352
# I0214 13:30:26.413573 11044 efficientnet_model.py:143] round_filter input=1280 output=1408
# I0214 13:30:26.483681 11044 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0214 13:30:26.544935 11044 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0214 13:30:26.544935 11044 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I0214 13:30:26.544935 11044 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I0214 13:30:26.553779 11044 efficientnet_model.py:143] round_filter input=32 output=40
# I0214 13:30:26.573652 11044 efficientnet_model.py:143] round_filter input=32 output=40
# I0214 13:30:26.573652 11044 efficientnet_model.py:143] round_filter input=16 output=24
# I0214 13:30:26.759771 11044 efficientnet_model.py:143] round_filter input=16 output=24
# I0214 13:30:26.759859 11044 efficientnet_model.py:143] round_filter input=24 output=32
# I0214 13:30:27.095005 11044 efficientnet_model.py:143] round_filter input=24 output=32
# I0214 13:30:27.095005 11044 efficientnet_model.py:143] round_filter input=40 output=48
# I0214 13:30:27.446023 11044 efficientnet_model.py:143] round_filter input=40 output=48
# I0214 13:30:27.446023 11044 efficientnet_model.py:143] round_filter input=80 output=96
# I0214 13:30:27.976025 11044 efficientnet_model.py:143] round_filter input=80 output=96
# I0214 13:30:27.976025 11044 efficientnet_model.py:143] round_filter input=112 output=136
# I0214 13:30:28.565017 11044 efficientnet_model.py:143] round_filter input=112 output=136
# I0214 13:30:28.565017 11044 efficientnet_model.py:143] round_filter input=192 output=232
# I0214 13:30:29.288449 11044 efficientnet_model.py:143] round_filter input=192 output=232
# I0214 13:30:29.288449 11044 efficientnet_model.py:143] round_filter input=320 output=384
# I0214 13:30:29.564762 11044 efficientnet_model.py:143] round_filter input=1280 output=1536
# I0214 13:30:29.638773 11044 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0214 13:30:29.726019 11044 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0214 13:30:29.726019 11044 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 224
# I0214 13:30:29.726019 11044 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0214 13:30:29.727852 11044 efficientnet_model.py:143] round_filter input=32 output=48
# I0214 13:30:29.746021 11044 efficientnet_model.py:143] round_filter input=32 output=48
# I0214 13:30:29.746021 11044 efficientnet_model.py:143] round_filter input=16 output=24
# I0214 13:30:29.918538 11044 efficientnet_model.py:143] round_filter input=16 output=24
# I0214 13:30:29.918538 11044 efficientnet_model.py:143] round_filter input=24 output=32
# I0214 13:30:30.423616 11044 efficientnet_model.py:143] round_filter input=24 output=32
# I0214 13:30:30.423616 11044 efficientnet_model.py:143] round_filter input=40 output=56
# I0214 13:30:30.846014 11044 efficientnet_model.py:143] round_filter input=40 output=56
# I0214 13:30:30.846014 11044 efficientnet_model.py:143] round_filter input=80 output=112
# I0214 13:30:31.506029 11044 efficientnet_model.py:143] round_filter input=80 output=112
# I0214 13:30:31.506029 11044 efficientnet_model.py:143] round_filter input=112 output=160
# I0214 13:30:32.196010 11044 efficientnet_model.py:143] round_filter input=112 output=160
# I0214 13:30:32.196010 11044 efficientnet_model.py:143] round_filter input=192 output=272
# I0214 13:30:33.265864 11044 efficientnet_model.py:143] round_filter input=192 output=272
# I0214 13:30:33.265864 11044 efficientnet_model.py:143] round_filter input=320 output=448
# I0214 13:30:33.573733 11044 efficientnet_model.py:143] round_filter input=1280 output=1792
# I0214 13:30:33.643676 11044 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0214 13:30:33.738672 11044 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0214 13:30:33.738672 11044 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0214 13:30:33.738672 11044 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0214 13:30:33.741266 11044 efficientnet_model.py:143] round_filter input=32 output=48
# I0214 13:30:33.756028 11044 efficientnet_model.py:143] round_filter input=32 output=48
# I0214 13:30:33.756028 11044 efficientnet_model.py:143] round_filter input=16 output=24
# I0214 13:30:34.224375 11044 efficientnet_model.py:143] round_filter input=16 output=24
# I0214 13:30:34.224375 11044 efficientnet_model.py:143] round_filter input=24 output=40
# I0214 13:30:34.745723 11044 efficientnet_model.py:143] round_filter input=24 output=40
# I0214 13:30:34.745723 11044 efficientnet_model.py:143] round_filter input=40 output=64
# I0214 13:30:35.348839 11044 efficientnet_model.py:143] round_filter input=40 output=64
# I0214 13:30:35.348839 11044 efficientnet_model.py:143] round_filter input=80 output=128
# I0214 13:30:36.143693 11044 efficientnet_model.py:143] round_filter input=80 output=128
# I0214 13:30:36.143693 11044 efficientnet_model.py:143] round_filter input=112 output=176
# I0214 13:30:36.945936 11044 efficientnet_model.py:143] round_filter input=112 output=176
# I0214 13:30:36.945936 11044 efficientnet_model.py:143] round_filter input=192 output=304
# I0214 13:30:38.173680 11044 efficientnet_model.py:143] round_filter input=192 output=304
# I0214 13:30:38.175075 11044 efficientnet_model.py:143] round_filter input=320 output=512
# I0214 13:30:38.725604 11044 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0214 13:30:38.803811 11044 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0214 13:30:38.913856 11044 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0214 13:30:38.913856 11044 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0214 13:30:38.918688 11044 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0214 13:30:38.919698 11044 efficientnet_model.py:143] round_filter input=32 output=56
# I0214 13:30:38.938822 11044 efficientnet_model.py:143] round_filter input=32 output=56
# I0214 13:30:38.938822 11044 efficientnet_model.py:143] round_filter input=16 output=32
# I0214 13:30:39.240415 11044 efficientnet_model.py:143] round_filter input=16 output=32
# I0214 13:30:39.240415 11044 efficientnet_model.py:143] round_filter input=24 output=40
# I0214 13:30:39.945961 11044 efficientnet_model.py:143] round_filter input=24 output=40
# I0214 13:30:39.945961 11044 efficientnet_model.py:143] round_filter input=40 output=72
# I0214 13:30:40.593594 11044 efficientnet_model.py:143] round_filter input=40 output=72
# I0214 13:30:40.593594 11044 efficientnet_model.py:143] round_filter input=80 output=144
# I0214 13:30:41.504745 11044 efficientnet_model.py:143] round_filter input=80 output=144
# I0214 13:30:41.504745 11044 efficientnet_model.py:143] round_filter input=112 output=200
# I0214 13:30:42.448807 11044 efficientnet_model.py:143] round_filter input=112 output=200
# I0214 13:30:42.448807 11044 efficientnet_model.py:143] round_filter input=192 output=344
# I0214 13:30:44.399473 11044 efficientnet_model.py:143] round_filter input=192 output=344
# I0214 13:30:44.400087 11044 efficientnet_model.py:143] round_filter input=320 output=576
# I0214 13:30:44.996267 11044 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0214 13:30:45.105877 11044 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0214 13:30:45.245814 11044 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0214 13:30:45.245814 11044 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0214 13:30:45.245814 11044 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0214 13:30:45.251320 11044 efficientnet_model.py:143] round_filter input=32 output=64
# I0214 13:30:45.276622 11044 efficientnet_model.py:143] round_filter input=32 output=64
# I0214 13:30:45.276622 11044 efficientnet_model.py:143] round_filter input=16 output=32
# I0214 13:30:45.664234 11044 efficientnet_model.py:143] round_filter input=16 output=32
# I0214 13:30:45.664853 11044 efficientnet_model.py:143] round_filter input=24 output=48
# I0214 13:30:46.518628 11044 efficientnet_model.py:143] round_filter input=24 output=48
# I0214 13:30:46.518628 11044 efficientnet_model.py:143] round_filter input=40 output=80
# I0214 13:30:47.318497 11044 efficientnet_model.py:143] round_filter input=40 output=80
# I0214 13:30:47.318497 11044 efficientnet_model.py:143] round_filter input=80 output=160
# I0214 13:30:49.027028 11044 efficientnet_model.py:143] round_filter input=80 output=160
# I0214 13:30:49.028122 11044 efficientnet_model.py:143] round_filter input=112 output=224
# I0214 13:30:50.505916 11044 efficientnet_model.py:143] round_filter input=112 output=224
# I0214 13:30:50.505916 11044 efficientnet_model.py:143] round_filter input=192 output=384
# I0214 13:30:52.405955 11044 efficientnet_model.py:143] round_filter input=192 output=384
# I0214 13:30:52.406974 11044 efficientnet_model.py:143] round_filter input=320 output=640
# I0214 13:30:53.185779 11044 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0214 13:30:53.275820 11044 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 34.98s
# I0214 13:30:53.453390 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 34.98s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# I0214 13:30:53.483504 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0214 13:30:53.485745 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0214 13:30:53.486815 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0214 13:30:53.487849 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0214 13:30:53.489973 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0214 13:30:53.490414 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0214 13:30:53.491448 11044 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 41.919s
#
# OK (skipped=1)

# %%
# !pip install tensorflow

# %%
# !pip install keras --upgrade

# %%
# !python -m pip install tf-models-official
# Out:
# Collecting tf-models-official
#   Using cached tf_models_official-2.11.3-py2.py3-none-any.whl (2.3 MB)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (9.0.0)
# Collecting pycocotools
#   Using cached pycocotools-2.0.6-cp310-cp310-win_amd64.whl
# Collecting seqeval
#   Using cached seqeval-1.2.2-py3-none-any.whl
# Collecting kaggle>=1.3.9
#   Using cached kaggle-1.5.12-py3-none-any.whl
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (0.7.3)
# Collecting tf-models-official
#   Using cached tf_models_official-2.11.2-py2.py3-none-any.whl (2.3 MB)
#   Using cached tf_models_official-2.11.0-py2.py3-none-any.whl (2.3 MB)
#   Using cached tf_models_official-2.10.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied: sentencepiece in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (0.1.97)
# Collecting oauth2client
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (1.10.0)
# Collecting tensorflow-datasets
#   Using cached tensorflow_datasets-4.8.2-py3-none-any.whl (5.3 MB)
# Requirement already satisfied: gin-config in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (0.5.0)
# Collecting pandas>=0.22.0
#   Using cached pandas-1.5.3-cp310-cp310-win_amd64.whl (10.4 MB)
# Collecting tensorflow-text~=2.10.0
#   Using cached tensorflow_text-2.10.0-cp310-cp310-win_amd64.whl (5.0 MB)
# Requirement already satisfied: psutil>=5.4.3 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (5.9.4)
# Collecting tensorflow-addons
#   Using cached tensorflow_addons-0.19.0-cp310-cp310-win_amd64.whl (732 kB)
# Collecting Cython
#   Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
# Collecting tensorflow~=2.10.0
#   Using cached tensorflow-2.10.1-cp310-cp310-win_amd64.whl (455.9 MB)
# Requirement already satisfied: numpy>=1.20 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (1.24.2)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (5.4.1)
# Collecting immutabledict
#   Using cached immutabledict-2.2.3-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: sacrebleu==2.2.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages\sacrebleu-2.2.0-py3.10.egg (from tf-models-official) (2.2.0)
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.7.0.68-cp37-abi3-win_amd64.whl (38.1 MB)
# Requirement already satisfied: Pillow in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (9.4.0)
# Requirement already satisfied: tf-slim>=1.1.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (1.1.0)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (0.12.0)
# Requirement already satisfied: six in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (1.16.0)
# Collecting google-api-python-client>=1.6.7
#   Using cached google_api_python_client-2.77.0-py2.py3-none-any.whl (11.0 MB)
# Requirement already satisfied: matplotlib in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tf-models-official) (3.7.0)
# Requirement already satisfied: colorama in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from sacrebleu==2.2.0->tf-models-official) (0.4.6)
# Requirement already satisfied: lxml in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from sacrebleu==2.2.0->tf-models-official) (4.9.2)
# Requirement already satisfied: portalocker in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from sacrebleu==2.2.0->tf-models-official) (2.7.0)
# Requirement already satisfied: regex in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from sacrebleu==2.2.0->tf-models-official) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from sacrebleu==2.2.0->tf-models-official) (0.9.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official) (4.1.1)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Using cached google_api_core-2.11.0-py3-none-any.whl (120 kB)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.16.0)
# Collecting httplib2<1dev,>=0.15.0
#   Using cached httplib2-0.21.0-py3-none-any.whl (96 kB)
# Collecting google-auth-httplib2>=0.1.0
#   Using cached google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: requests in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from kaggle>=1.3.9->tf-models-official) (2.28.2)
# Requirement already satisfied: python-slugify in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from kaggle>=1.3.9->tf-models-official) (8.0.0)
# Requirement already satisfied: certifi in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from kaggle>=1.3.9->tf-models-official) (2022.12.7)
# Requirement already satisfied: python-dateutil in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from kaggle>=1.3.9->tf-models-official) (2.8.2)
# Requirement already satisfied: tqdm in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from kaggle>=1.3.9->tf-models-official) (4.64.1)
# Requirement already satisfied: urllib3 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from kaggle>=1.3.9->tf-models-official) (1.26.14)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from pandas>=0.22.0->tf-models-official) (2022.7.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (0.30.0)
# Collecting tensorboard<2.11,>=2.10
#   Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (1.51.1)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (0.4.0)
# Requirement already satisfied: packaging in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (23.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (1.4.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (15.0.6.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (23.1.21)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (2.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (2.10.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (3.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (4.4.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow~=2.10.0->tf-models-official) (58.1.0)
# Requirement already satisfied: dm-tree~=0.1.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official) (0.1.8)
# Requirement already satisfied: cycler>=0.10 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from matplotlib->tf-models-official) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from matplotlib->tf-models-official) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages\pyparsing-2.4.7-py3.10.egg (from matplotlib->tf-models-official) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from matplotlib->tf-models-official) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from matplotlib->tf-models-official) (4.38.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from oauth2client->tf-models-official) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from oauth2client->tf-models-official) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from oauth2client->tf-models-official) (4.9)
# Collecting scikit-learn>=0.21.3
#   Using cached scikit_learn-1.2.1-cp310-cp310-win_amd64.whl (8.3 MB)
# Requirement already satisfied: typeguard>=2.7 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow-addons->tf-models-official) (2.13.3)
# Collecting dill
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Collecting tensorflow-metadata
#   Using cached tensorflow_metadata-1.12.0-py3-none-any.whl (52 kB)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: toml in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow-datasets->tf-models-official) (0.10.2)
# Requirement already satisfied: promise in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorflow-datasets->tf-models-official) (2.3)
# Collecting etils[enp,epath]>=0.9.0
#   Using cached etils-1.0.0-py3-none-any.whl (146 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from astunparse>=1.6.0->tensorflow~=2.10.0->tf-models-official) (0.38.4)
# Collecting importlib_resources
#   Using cached importlib_resources-5.10.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: zipp in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official) (3.13.0)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Using cached googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official) (5.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from requests->kaggle>=1.3.9->tf-models-official) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from requests->kaggle>=1.3.9->tf-models-official) (3.4)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (3.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official) (3.4.1)
# Requirement already satisfied: pywin32>=226 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from portalocker->sacrebleu==2.2.0->tf-models-official) (305)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official) (2.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official) (3.2.2)
# Installing collected packages: tensorflow-addons, opencv-python-headless, keras-preprocessing, joblib, importlib_resources, immutabledict, httplib2, googleapis-common-protos, etils, dill, Cython, click, tensorflow-metadata, scikit-learn, pandas, oauth2client, kaggle, seqeval, pycocotools, google-auth-httplib2, google-api-core, tensorflow-datasets, tensorboard, google-api-python-client, tensorflow, tensorflow-text, tf-models-official
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# Successfully installed Cython-0.29.33 click-8.1.3 dill-0.3.6 etils-1.0.0 google-api-core-2.11.0 google-api-python-client-2.77.0 google-auth-httplib2-0.1.0 googleapis-common-protos-1.58.0 httplib2-0.21.0 immutabledict-2.2.3 importlib_resources-5.10.2 joblib-1.2.0 kaggle-1.5.12 keras-preprocessing-1.1.2 oauth2client-4.1.3 opencv-python-headless-4.7.0.68 pandas-1.5.3 pycocotools-2.0.6 scikit-learn-1.2.1 seqeval-1.2.2 tensorboard-2.10.1 tensorflow-2.10.1 tensorflow-addons-0.19.0 tensorflow-datasets-4.8.2 tensorflow-metadata-1.12.0 tensorflow-text-2.10.0 tf-models-official-2.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# object-detection 0.1 requires apache-beam, which is not installed.
# object-detection 0.1 requires avro-python3, which is not installed.
# object-detection 0.1 requires contextlib2, which is not installed.
# object-detection 0.1 requires lvis, which is not installed.
# tensorflow-intel 2.11.0 requires keras<2.12,>=2.11.0, but you have keras 2.10.0 which is incompatible.
# tensorflow-intel 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.10.1 which is incompatible.
# tensorflow-intel 2.11.0 requires tensorflow-estimator<2.12,>=2.11.0, but you have tensorflow-estimator 2.10.0 which is incompatible.

# %%
# !pip install tensorflow_io

# %%
# !pip install tensorflow --upgrade

# %%
# !pip install scipy

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
# !pip install matplotlib

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                       Version    Editable project location
# ----------------------------- ---------- -------------------------------------------------------------------------------------------------------------------------------------------
# absl-py                       1.4.0
# asttokens                     2.2.1
# astunparse                    1.6.3
# backcall                      0.2.0
# cachetools                    5.3.0
# certifi                       2022.12.7
# charset-normalizer            3.0.1
# click                         8.1.3
# colorama                      0.4.6
# comm                          0.1.2
# contourpy                     1.0.7
# cycler                        0.11.0
# Cython                        0.29.33
# debugpy                       1.6.6
# decorator                     5.1.1
# dill                          0.3.6
# dm-tree                       0.1.8
# etils                         1.0.0
# executing                     1.2.0
# flatbuffers                   23.1.21
# fonttools                     4.38.0
# gast                          0.4.0
# gin-config                    0.5.0
# google-api-core               2.11.0
# google-api-python-client      2.77.0
# google-auth                   2.16.0
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# googleapis-common-protos      1.58.0
# grpcio                        1.51.1
# h5py                          3.8.0
# httplib2                      0.21.0
# idna                          3.4
# immutabledict                 2.2.3
# importlib-resources           5.10.2
# ipykernel                     6.21.1
# ipython                       8.9.0
# jedi                          0.18.2
# joblib                        1.2.0
# jupyter_client                8.0.2
# jupyter_core                  5.2.0
# kaggle                        1.5.12
# keras                         2.10.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.4.4
# libclang                      15.0.6.1
# lxml                          4.9.2
# Markdown                      3.4.1
# MarkupSafe                    2.1.2
# matplotlib                    3.7.0
# matplotlib-inline             0.1.6
# nest-asyncio                  1.5.6
# numpy                         1.24.2
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# object-detection              0.1
# opencv-python                 4.7.0.68
# opencv-python-headless        4.7.0.68
# opt-einsum                    3.3.0
# packaging                     23.0
# pandas                        1.5.3
# parso                         0.8.3
# pickleshare                   0.7.5
# Pillow                        9.4.0
# pip                           23.0
# platformdirs                  3.0.0
# portalocker                   2.7.0
# promise                       2.3
# prompt-toolkit                3.0.36
# protobuf                      3.19.6
# psutil                        5.9.4
# pure-eval                     0.2.2
# py-cpuinfo                    9.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.6
# Pygments                      2.14.0
# pyparsing                     2.4.7
# PyQt5                         5.15.9
# PyQt5-Qt5                     5.15.2
# PyQt5-sip                     12.11.1
# python-dateutil               2.8.2
# python-slugify                8.0.0
# pytz                          2022.7.1
# pywin32                       305
# PyYAML                        5.4.1
# pyzmq                         25.0.0
# regex                         2022.10.31
# requests                      2.28.2
# requests-oauthlib             1.3.1
# rsa                           4.9
# sacrebleu                     2.2.0
# scikit-learn                  1.2.1
# scipy                         1.10.0
# sentencepiece                 0.1.97
# seqeval                       1.2.2
# setuptools                    58.1.0
# six                           1.16.0
# slim                          0.1        c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\tensorflow\models\research\slim
# stack-data                    0.6.2
# tabulate                      0.9.0
# tensorboard                   2.10.1
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.10.1
# tensorflow-addons             0.19.0
# tensorflow-datasets           4.8.2
# tensorflow-estimator          2.10.0
# tensorflow-hub                0.12.0
# tensorflow-intel              2.11.0
# tensorflow-io                 0.30.0
# tensorflow-io-gcs-filesystem  0.30.0
# tensorflow-metadata           1.12.0
# tensorflow-model-optimization 0.7.3
# tensorflow-text               2.10.0
# termcolor                     2.2.0
# text-unidecode                1.3
# tf-models-official            2.10.1
# tf-slim                       1.1.0
# threadpoolctl                 3.1.0
# toml                          0.10.2
# tornado                       6.2
# tqdm                          4.64.1
# traitlets                     5.9.0
# typeguard                     2.13.3
# typing_extensions             4.4.0
# uritemplate                   4.1.1
# urllib3                       1.26.14
# wcwidth                       0.2.6
# Werkzeug                      2.2.2
# wget                          3.2
# wheel                         0.38.4
# wrapt                         1.14.1
# zipp                          3.13.0

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# 100% [.......................................................................] 20515344 / 20515344        1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'BlackTip', 'id':1}, {'name':'Nurse', 'id':2}, {'name':'Tiger', 'id':3}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
# !pip install lvis
# Out:
# Collecting lvis
#   Using cached lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: kiwisolver>=1.1.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from lvis) (1.4.4)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from lvis) (1.24.2)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from lvis) (3.7.0)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from lvis) (0.11.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from lvis) (4.7.0.68)
# Requirement already satisfied: pyparsing>=2.4.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages\pyparsing-2.4.7-py3.10.egg (from lvis) (2.4.7)
# Requirement already satisfied: Cython>=0.29.12 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from lvis) (0.29.33)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from lvis) (2.8.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from lvis) (1.16.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from matplotlib>=3.1.1->lvis) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from matplotlib>=3.1.1->lvis) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from matplotlib>=3.1.1->lvis) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matte\documents\tcdcollege\4-fourthyear\csu44099-finalyearproject\fishnet\shark-species-identifier\identificationsystem\lib\site-packages (from matplotlib>=3.1.1->lvis) (1.0.7)
# Installing collected packages: lvis
# Successfully installed lvis-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# object-detection 0.1 requires apache-beam, which is not installed.
# object-detection 0.1 requires avro-python3, which is not installed.
# object-detection 0.1 requires contextlib2, which is not installed.

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=2000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'tiger.00000004.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Detect Species based on Video

# %% [markdown]
# # 11. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)

# %% [markdown]
# # 12. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
